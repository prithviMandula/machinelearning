# %%
import numpy as np
import pandas as pd
from keras import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/prithviMandula/machinelearning/master/healthcare/diabetes/diabetesdata.csv")

# %%
dataset.head()
# Out:
#    ReportingStatus  RelativeStrength  ProfitMN  SalesMN  ProfitPercent  \
# 0                0                57     1.225      6.5             64
# 1                0                51     1.469      9.9             56
# 2                0                79     0.887      7.0             59
# 3                0                55     1.316      8.9             34
# 4                1                32     1.010      5.7             43
#
#    Joint Bid
# 0         59
# 1         58
# 2         48
# 3         41
# 4         63

# %%
X= dataset.drop("ReportingStatus", axis=1)
y=dataset["ReportingStatus"]

# %%
#standardizing the input feature
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
X
# Out:
# array([[ 0.37519263,  0.42525023, -0.86817627,  1.45538612, -0.09423622],
#        [-0.09139559,  0.90674652,  0.82362545,  0.67737497, -0.18296732],
#        [ 2.08601612, -0.24174054, -0.6193819 ,  0.96912915, -1.07027825],
#        ...,
#        [ 2.08601612,  0.44695703, -0.4203464 ,  1.06638054, -0.09423622],
#        [-0.71351322, -0.59694273,  1.17193757, -0.29513897, -0.18296732],
#        [-0.71351322, -0.07203283,  0.87338433, -1.85116128,  0.7930747 ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
classifier = Sequential()
classifier.add(Dense(5, activation='relu', kernel_initializer='random_normal', input_dim=5))
classifier.add(Dense(3, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))

classifier.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size=5, epochs=200)
# Out:
# WARNING:tensorflow:From C:\Users\IronMan\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/200
# 2775/2775 [==============================] - 1s 369us/step - loss: 0.5297 - acc: 0.8126
# Epoch 2/200
# 2775/2775 [==============================] - 1s 227us/step - loss: 0.1611 - acc: 0.9643
# Epoch 3/200
# 2775/2775 [==============================] - 1s 228us/step - loss: 0.1139 - acc: 0.9661
# Epoch 4/200
# 2775/2775 [==============================] - 1s 230us/step - loss: 0.1051 - acc: 0.9632
# Epoch 5/200
# 2775/2775 [==============================] - 1s 230us/step - loss: 0.1013 - acc: 0.9629
# Epoch 6/200
# 2775/2775 [==============================] - 1s 228us/step - loss: 0.0994 - acc: 0.9636
# Epoch 7/200
# ...

# %%
eval_model=classifier.evaluate(X_test, y_test)
eval_model
# Out:
# 1190/1190 [==============================] - 0s 72us/step
# [0.12870959694645986, 0.9563025210084034]

# %%
y_pred=classifier.predict(X_test)
y_pred =(y_pred>0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[594  22]
#  [ 30 544]]

# %%
classifier = Sequential()
classifier.add(Dense(5, activation='relu', kernel_initializer='random_normal', input_dim=5))
classifier.add(Dense(26, activation='relu', kernel_initializer='random_normal'))
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))

classifier.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size=5, epochs=50)
# Out:
# Epoch 1/50
# 2775/2775 [==============================] - 1s 418us/step - loss: 0.4386 - acc: 0.8267
# Epoch 2/50
# 2775/2775 [==============================] - 1s 254us/step - loss: 0.1737 - acc: 0.9629
# Epoch 3/50
# 2775/2775 [==============================] - 1s 219us/step - loss: 0.1257 - acc: 0.9632
# Epoch 4/50
# 2775/2775 [==============================] - 1s 229us/step - loss: 0.1129 - acc: 0.9640
# Epoch 5/50
# 2775/2775 [==============================] - 1s 278us/step - loss: 0.1076 - acc: 0.9625
# Epoch 6/50
# 2775/2775 [==============================] - 1s 234us/step - loss: 0.1049 - acc: 0.9668
# Epoch 7/50
# 2775/2775 [==============================] - 1s 228us/step - loss: 0.1041 - acc: 0.9650
# Epoch 8/50
# 2775/2775 [==============================] - 1s 226us/step - loss: 0.1013 - acc: 0.9640
# Epoch 9/50
# 2775/2775 [==============================] - 1s 230us/step - loss: 0.1012 - acc: 0.9622
# Epoch 10/50
# ...

# %%
eval_model = classifier.evaluate(X_test, y_test)
eval_model
# Out:
# 1190/1190 [==============================] - 0s 158us/step
# [0.1193618464244514, 0.9554621848739496]
